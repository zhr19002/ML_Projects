# %%
import matplotlib.pyplot as plt

rmse_LSTM = 0.404
rmse_arr_LSTM = [0.209, 0.279, 0.336, 0.380, 0.412, 0.432, 0.441, 0.445, 0.445, 0.460, 0.451, 0.465]

contexts = [24, 48, 72, 96, 120, 256, 512, 1024, 2048]
rmse_LLMs = [0.572, 0.547, 0.517, 0.501, 0.495, 0.461, 0.440, 0.425, 0.411]
durations = [256.70, 256.06, 257.72, 255.60, 282.01, 314.63, 407.98, 534.11, 872.33]

# ----- context = 24 ----- #
rmse_arr_24 = [0.227, 0.326, 0.407, 0.474, 0.530, 0.575, 0.612, 0.643, 0.670, 0.693, 0.713, 0.732]
# Test MAE: 0.389
# Test MAE per output: 0.158, 0.230, 0.287, 0.335, 0.375, 0.407, 0.434, 0.457, 0.474, 0.490, 0.503, 0.516
# Test R2: 0.428
# Test R2 per output: 0.910, 0.814, 0.710, 0.607, 0.508, 0.420, 0.345, 0.276, 0.215, 0.159, 0.109, 0.062

# ----- context = 48 ----- #
rmse_arr_48 = [0.228, 0.324, 0.399, 0.461, 0.512, 0.553, 0.586, 0.614, 0.638, 0.658, 0.674, 0.690]
# Test MAE: 0.371
# Test MAE per output: 0.159, 0.227, 0.279, 0.325, 0.360, 0.389, 0.412, 0.433, 0.449, 0.462, 0.473, 0.484
# Test R2: 0.477
# Test R2 per output: 0.909, 0.816, 0.722, 0.629, 0.541, 0.465, 0.399, 0.339, 0.288, 0.243, 0.204, 0.168

# ----- context = 72 ----- #
rmse_arr_72 = [0.219, 0.313, 0.384, 0.441, 0.487, 0.524, 0.553, 0.579, 0.600, 0.618, 0.635, 0.651]
# Test MAE: 0.352
# Test MAE per output: 0.155, 0.221, 0.270, 0.311, 0.343, 0.368, 0.389, 0.408, 0.422, 0.435, 0.445, 0.456
# Test R2: 0.532
# Test R2 per output: 0.916, 0.829, 0.742, 0.660, 0.584, 0.520, 0.464, 0.413, 0.370, 0.330, 0.294, 0.258

# ----- context = 96 ----- #
rmse_arr_96 = [0.216, 0.308, 0.378, 0.433, 0.477, 0.510, 0.536, 0.559, 0.578, 0.595, 0.610, 0.628]
# Test MAE: 0.341
# Test MAE per output: 0.152, 0.218, 0.266, 0.305, 0.335, 0.358, 0.377, 0.394, 0.406, 0.417, 0.427, 0.438
# Test R2: 0.560
# Test R2 per output: 0.918, 0.834, 0.750, 0.672, 0.602, 0.545, 0.496, 0.453, 0.415, 0.381, 0.347, 0.311

# ----- context = 120 ----- #
rmse_arr_120 = [0.215, 0.307, 0.376, 0.429, 0.472, 0.503, 0.529, 0.551, 0.570, 0.585, 0.601, 0.618]
# Test MAE: 0.337
# Test MAE per output: 0.151, 0.216, 0.264, 0.301, 0.330, 0.353, 0.371, 0.388, 0.401, 0.411, 0.420, 0.431
# Test R2: 0.572
# Test R2 per output: 0.919, 0.835, 0.753, 0.678, 0.611, 0.557, 0.510, 0.468, 0.432, 0.400, 0.368, 0.331

# ----- context = 256 ----- #
rmse_arr_256 = [0.214, 0.302, 0.365, 0.412, 0.449, 0.475, 0.495, 0.512, 0.525, 0.535, 0.546, 0.560]
# Test MAE: 0.319
# Test MAE per output: 0.150, 0.212, 0.258, 0.293, 0.319, 0.338, 0.353, 0.366, 0.375, 0.382, 0.389, 0.399
# Test R2: 0.628
# Test R2 per output: 0.920, 0.841, 0.767, 0.703, 0.648, 0.605, 0.570, 0.541, 0.518, 0.499, 0.478, 0.451

# ----- context = 512 ----- #
rmse_arr_512 = [0.209, 0.294, 0.354, 0.397, 0.430, 0.454, 0.472, 0.487, 0.499, 0.509, 0.519, 0.533]
# Test MAE: 0.308
# Test MAE per output: 0.148, 0.208, 0.251, 0.283, 0.307, 0.325, 0.338, 0.351, 0.360, 0.368, 0.375, 0.384
# Test R2: 0.661
# Test R2 per output: 0.923, 0.849, 0.780, 0.724, 0.676, 0.640, 0.610, 0.585, 0.564, 0.546, 0.528, 0.503
# PICP (80% PI): 68.7
# PICP (80% PI) per output: 73.9, 70.3, 69.9, 69.0, 68.6, 68.1, 67.9, 67.8, 67.2, 67.4, 67.6, 67.3
# PICP (95% PI): 91.5
# PICP (95% PI) per output: 95.6, 93.1, 92.8, 91.6, 91.1, 91.2, 90.6, 90.8, 90.4, 90.5, 90.4, 90.2
# MPIW (80% PI): 0.754
# MPIW (80% PI) per output: 0.415, 0.533, 0.632, 0.698, 0.748, 0.789, 0.816, 0.849, 0.864, 0.882, 0.901, 0.922
# MPIW (95% PI): 1.322
# MPIW (95% PI) per output: 0.813, 0.983, 1.132, 1.229, 1.307, 1.370, 1.412, 1.460, 1.494, 1.524, 1.552, 1.586

# ----- context = 1024 ----- #
rmse_arr_1024 = [0.204, 0.288, 0.346, 0.387, 0.418, 0.440, 0.455, 0.469, 0.480, 0.489, 0.498, 0.510]
# Test MAE: 0.300
# Test MAE per output: 0.145, 0.204, 0.246, 0.277, 0.300, 0.317, 0.330, 0.341, 0.349, 0.356, 0.363, 0.372
# Test R2: 0.684
# Test R2 per output: 0.927, 0.855, 0.791, 0.738, 0.694, 0.662, 0.637, 0.615, 0.596, 0.582, 0.566, 0.545
# PICP (80% PI): 68.1
# PICP (80% PI) per output: 74.1, 70.6, 69.9, 69.1, 68.0, 67.7, 66.7, 66.7, 66.2, 66.0, 66.0, 66.1
# PICP (95% PI): 91.6
# PICP (95% PI) per output: 95.6, 93.4, 92.8, 91.7, 91.4, 90.8, 90.6, 90.3, 90.3, 90.6, 91.0, 90.3
# MPIW (80% PI): 0.732
# MPIW (80% PI) per output: 0.410, 0.525, 0.620, 0.683, 0.730, 0.768, 0.791, 0.820, 0.834, 0.849, 0.868, 0.888
# MPIW (95% PI): 1.271
# MPIW (95% PI) per output: 0.792, 0.957, 1.098, 1.190, 1.262, 1.319, 1.357, 1.399, 1.430, 1.456, 1.483, 1.515

# ----- context = 2048 ----- #
rmse_arr_2048 = [0.200, 0.282, 0.337, 0.375, 0.405, 0.426, 0.440, 0.453, 0.463, 0.471, 0.479, 0.491]
# Test MAE: 0.293
# Test MAE per output: 0.142, 0.200, 0.241, 0.270, 0.293, 0.310, 0.321, 0.332, 0.341, 0.347, 0.353, 0.361
# Test R2: 0.705
# Test R2 per output: 0.930, 0.861, 0.801, 0.753, 0.713, 0.683, 0.661, 0.640, 0.624, 0.612, 0.598, 0.578
# PICP (80% PI): 67.4
# PICP (80% PI) per output: 74.2, 70.1, 69.1, 68.2, 67.6, 66.7, 66.2, 65.8, 65.5, 64.7, 65.4, 65.6
# PICP (95% PI): 91.1
# PICP (95% PI) per output: 95.4, 92.9, 92.4, 91.2, 90.9, 90.6, 90.3, 89.9, 89.9, 90.1, 89.9, 89.8
# MPIW (80% PI): 0.713
# MPIW (80% PI) per output: 0.399, 0.511, 0.604, 0.667, 0.712, 0.749, 0.771, 0.798, 0.811, 0.825, 0.845, 0.863
# MPIW (95% PI): 1.227
# MPIW (95% PI) per output: 0.763, 0.924, 1.061, 1.150, 1.220, 1.275, 1.311, 1.350, 1.378, 1.401, 1.429, 1.458

# %%
fig, ax1 = plt.subplots(figsize=(8, 4))

ax1.plot(contexts, rmse_LLMs, color='#4C72B0', marker='s', label='Chronos performance')
ax1.axhline(y=rmse_LSTM, color='#C44E52', linestyle='--', label='Attention-LSTM performance')
ax1.set_xscale('log')
ax1.set_xticks(contexts)
ax1.set_xticklabels([f'{c:g}' for c in contexts])
ax1.set_ylim(0.4, 0.58)
ax1.tick_params(axis='both', labelsize=11)
ax1.set_xlabel('Context Length (hours, log scale)', fontsize=12)
ax1.set_ylabel('RMSE (ft)', fontsize=12)

ax2 = ax1.twinx()
ax2.plot(contexts, durations, color='#D98C3B', linestyle='-.', marker='x', label='Chronos inference duration')
ax2.set_ylim(200, 900)
ax2.tick_params(axis='both', labelsize=11)
ax2.set_ylabel('Duration (seconds)', fontsize=12)

line1, label1 = ax1.get_legend_handles_labels()
line2, label2 = ax2.get_legend_handles_labels()
ax1.legend(line1 + line2, label1 + label2, fontsize=11, loc='upper center')
ax1.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
# plt.savefig('chronos_1.png', dpi=1200)
plt.show()

# %%
plt.figure(figsize=(8, 5))
cmap = plt.get_cmap('viridis', len(contexts))
rmse_arrs = [rmse_arr_24, rmse_arr_48, rmse_arr_72, rmse_arr_96, rmse_arr_120, rmse_arr_256, rmse_arr_512, rmse_arr_1024, rmse_arr_2048]

for i, context in enumerate(contexts):
    plt.plot(range(1, 13), rmse_arrs[i], color=cmap(i), marker='o', label=f'context = {context}')

plt.plot(range(1, 13), rmse_arr_LSTM, color='#C44E52', linestyle='--', linewidth=2, marker='x', label='Attention-LSTM')
plt.xticks(range(1, 13, 1))
plt.tick_params(axis='both', labelsize=11)
plt.xlabel('Lead Time (hours)', fontsize=12)
plt.ylabel('RMSE (ft)', fontsize=12)
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
# plt.savefig('chronos_2.png', dpi=1200)
plt.show()
